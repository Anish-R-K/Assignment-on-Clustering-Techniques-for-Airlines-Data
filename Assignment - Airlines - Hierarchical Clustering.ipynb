# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
xls=pd.ExcelFile('EastWestAirlines.xlsx')
df1=pd.read_excel(xls,'data')
df1
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df1.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
scaler=MinMaxScaler()
x=pd.DataFrame(scaler.fit_transform(df1.iloc[:,1:]))
x
# Out:
#              0    1     2    3    4         5         6         7         8  \
# 0     0.016508  0.0  0.00  0.0  0.0  0.000660  0.011628  0.000000  0.000000
# 1     0.011288  0.0  0.00  0.0  0.0  0.000815  0.023256  0.000000  0.000000
# 2     0.024257  0.0  0.00  0.0  0.0  0.015636  0.046512  0.000000  0.000000
# 3     0.008667  0.0  0.00  0.0  0.0  0.001896  0.011628  0.000000  0.000000
# 4     0.057338  0.0  0.75  0.0  0.0  0.164211  0.302326  0.067398  0.075472
# ...        ...  ...   ...  ...  ...       ...       ...       ...       ...
# 3994  0.010837  0.0  0.00  0.0  0.0  0.032330  0.046512  0.006490  0.018868
# 3995  0.037766  0.0  0.00  0.0  0.0  0.003720  0.058140  0.000000  0.000000
# 3996  0.043169  0.0  0.50  0.0  0.0  0.096505  0.093023  0.000000  0.000000
# 3997  0.032202  0.0  0.00  0.0  0.0  0.001896  0.011628  0.016225  0.018868
# 3998  0.001769  0.0  0.00  0.0  0.0  0.000000  0.000000  0.000000  0.000000
#
#              9   10
# 0     0.843742  0.0
# ...

# %%
# Dendrogram
from scipy.cluster.hierarchy import linkage
import scipy.cluster.hierarchy as sch
z=linkage(x,method='complete',metric='euclidean')
plt.figure(figsize=(15,5))
sch.dendrogram(z)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Dendrogram')
plt.show()

# %% [markdown]
# ### Dendrograms using several methods

# %%
# Dendrogram
from scipy.cluster.hierarchy import linkage
import scipy.cluster.hierarchy as sch
z=linkage(x,method='single',metric='euclidean')
plt.figure(figsize=(15,5))
sch.dendrogram(z)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Dendrogram')
plt.show()

# %%
x1=linkage(x,method='centroid',metric='euclidean')
plt.figure(figsize=(15,5))
sch.dendrogram(x1)
plt.show()

# %%
y=linkage(x,method='average',metric='euclidean')
plt.figure(figsize=(15,5))
sch.dendrogram(y)
plt.show()

# %%
# It is not possible to select the number of clusters by Hierarchial Method for this problem.
